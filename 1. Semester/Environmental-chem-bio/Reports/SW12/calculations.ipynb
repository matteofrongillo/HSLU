# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Data for all compounds
concentration = np.array([938975, 1093694, 1306917, 1134899, 1115451, 1358324, 1533223, 133907, 992122])
peak_area = np.array([4.62, 7.78, 8.18, 9.35, 11.58, 14.46, 15.00, 18.08, 18.21])

# Reshape data for sklearn
concentration = concentration.reshape(-1, 1)

# Perform Linear Regression
model = LinearRegression()
model.fit(concentration, peak_area)

# Get slope (m) and intercept (b)
m = model.coef_[0]
b = model.intercept_

# Print the equation of the line
print(f"Equation of the line: Peak Area = {m:.2f} * Concentration + {b:.2f}")

# Plot data and regression line
plt.scatter(concentration, peak_area, color='blue', label='Data points')
plt.plot(concentration, model.predict(concentration), color='red', label=f'Fit Line: y={m:.2f}x+{b:.2f}')
plt.xlabel('Concentration (ng/mL)')
plt.ylabel('Peak Area')
plt.title('Calibration Curve')
plt.legend()
plt.grid()
plt.show()
# Out:
# Equation of the line: Peak Area = -0.00 * Concentration + 15.57
